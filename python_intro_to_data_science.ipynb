# %% [markdown]
# <a href="https://colab.research.google.com/github/SHP2025/arcgis-experience-builder-sdk-resources/blob/master/python_intro_to_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NumPy**

# %%
import numpy as np

# %%
np1=np.array([0,1,"bob",2,3,4,5,6,7,8])
print(np1[2])
# Out:
# bob
